# %% [markdown]
# <a href="https://colab.research.google.com/github/Emmi-1406/FML/blob/main/Fifa19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sbn

# %%
data = pd.read_csv('/content/FIFA-2019.csv')

# %%
data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
data.tail()
# Out:
#       Unnamed: 0      ID        Name  Age  \
# 6243        6243  240802    J. Repas   21
# 6244        6244  135587  N. Mäenpää   33
# 6245        6245  212643  P. Cibicki   24
# 6246        6246  222883    T. Touré   24
# 6247        6247  245411   T. Jibril   20
#
#                                                Photo  Nationality  \
# 6243  https://cdn.sofifa.org/players/4/19/240802.png     Slovenia
# 6244  https://cdn.sofifa.org/players/4/19/135587.png      Finland
# 6245  https://cdn.sofifa.org/players/4/19/212643.png       Sweden
# 6246  https://cdn.sofifa.org/players/4/19/222883.png  Ivory Coast
# 6247  https://cdn.sofifa.org/players/4/19/245411.png      Nigeria
#
#                                       Flag  Overall  Potential  \
# 6243   https://cdn.sofifa.org/flags/44.png       69         80
# 6244   https://cdn.sofifa.org/flags/17.png       69         69
# 6245   https://cdn.sofifa.org/flags/46.png       69         74
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0             ID          Age      Overall    Potential  \
# count  6248.000000    6248.000000  6248.000000  6248.000000  6248.000000
# mean   3123.500000  201153.869718    27.142766    73.582746    76.031530
# std    1803.786573   30900.577868     4.082561     3.918802     4.882758
# min       0.000000      16.000000    17.000000    69.000000    69.000000
# 25%    1561.750000  188533.000000    24.000000    71.000000    72.000000
# 50%    3123.500000  205276.000000    27.000000    73.000000    75.000000
# 75%    4685.250000  222360.500000    30.000000    76.000000    79.000000
# max    6247.000000  246405.000000    45.000000    94.000000    95.000000
#
#            Special  International Reputation    Weak Foot  Skill Moves  \
# count  6248.000000               6248.000000  6248.000000  6248.000000
# mean   1773.030410                  1.317222     3.088988     2.710948
# std     240.697923                  0.612718     0.698798     0.826561
# ...

# %%
data.shape
# Out:
# (6248, 89)

# %%
data.isnull()
# Out:
#       Unnamed: 0     ID   Name    Age  Photo  Nationality   Flag  Overall  \
# 0          False  False  False  False  False        False  False    False
# 1          False  False  False  False  False        False  False    False
# 2          False  False  False  False  False        False  False    False
# 3          False  False  False  False  False        False  False    False
# 4          False  False  False  False  False        False  False    False
# ...          ...    ...    ...    ...    ...          ...    ...      ...
# 6243       False  False  False  False  False        False  False    False
# 6244       False  False  False  False  False        False  False    False
# 6245       False  False  False  False  False        False  False    False
# 6246       False  False  False  False  False        False  False    False
# 6247       False  False  False  False  False        False  False    False
#
#       Potential   Club  ...  Composure  Marking  StandingTackle  \
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# ID                  0
# Name                0
# Age                 0
# Photo               0
#                  ...
# GKHandling          1
# GKKicking           1
# GKPositioning       1
# GKReflexes          1
# Release Clause    592
# Length: 89, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6248 entries, 0 to 6247
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                6248 non-null   int64
#  1   ID                        6248 non-null   int64
#  2   Name                      6248 non-null   object
#  3   Age                       6248 non-null   int64
#  4   Photo                     6248 non-null   object
#  5   Nationality               6248 non-null   object
#  6   Flag                      6248 non-null   object
#  7   Overall                   6248 non-null   int64
#  8   Potential                 6248 non-null   int64
#  9   Club                      6148 non-null   object
#  10  Club Logo                 6248 non-null   object
#  11  Value                     6248 non-null   object
#  12  Wage                      6248 non-null   object
# ...

# %%
data['Age'].fillna(27.142766,inplace=True)
print('No.of null values in age column is:',data['Age'].isnull().sum())
# Out:
# No.of null values in age column is: 0

# %%
data['Age'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6243    False
# 6244    False
# 6245    False
# 6246    False
# 6247    False
# Name: Age, Length: 6248, dtype: bool

# %%
data.size
# Out:
# 556072

# %%
data['Age'].dropna()
# Out:
# 0       31
# 1       33
# 2       26
# 3       27
# 4       27
#         ..
# 6243    21
# 6244    33
# 6245    24
# 6246    24
# 6247    20
# Name: Age, Length: 6248, dtype: int64
